# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - accuracy: 0.9914 - loss: 0.0242 - val_accuracy: 0.8864 - val_loss: 1.1134
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.9915 - loss: 0.0242 - val_accuracy: 0.8820 - val_loss: 1.1777
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 24ms/step - accuracy: 0.9919 - loss: 0.0223 - val_accuracy: 0.8800 - val_loss: 1.1719
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.9923 - loss: 0.0228 - val_accuracy: 0.8827 - val_loss: 1.1749
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.9905 - loss: 0.0264 - val_accuracy: 0.8850 - val_loss: 1.1967
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.9914 - loss: 0.0234 - val_accuracy: 0.8818 - val_loss: 1.1919
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 31s 33ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.8815 - val_loss: 1.2342
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.9926 - loss: 0.0206 - val_accuracy: 0.8830 - val_loss: 1.2281
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.9929 - loss: 0.0194 - val_accuracy: 0.8783 - val_loss: 1.2806
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.9933 - loss: 0.0188 - val_accuracy: 0.8848 - val_loss: 1.2708
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9930 - loss: 0.0200 - val_accuracy: 0.8806 - val_loss: 1.2727
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.9930 - loss: 0.0221 - val_accuracy: 0.8808 - val_loss: 1.3103
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 24ms/step - accuracy: 0.9942 - loss: 0.0163 - val_accuracy: 0.8829 - val_loss: 1.3289
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.9933 - loss: 0.0191 - val_accuracy: 0.8838 - val_loss: 1.3034

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.993316650390625
# Validation Acc 0.8838000297546387

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D, Dense
from tensorflow.keras import Model

# Input layer for grayscale images
inputs = Input(shape=(28, 28, 1))

# Block 1
net = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

# Block 2
net = Conv2D(64, (3, 3), activation='relu', padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

# Block 3
net = Conv2D(128, (3, 3), activation='relu', padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

# Global Average Pooling
net = GlobalAveragePooling2D()(net)

# Fully connected layer
net = Dense(128, activation='relu')(net)
net = Dropout(0.5)(net)

# Output layer
outputs = Dense(10, activation='softmax')(net)

# Build the model
model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,370 (435.04 KB)
#  Trainable params: 110,922 (433.29 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Train the network
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 38ms/step - accuracy: 0.7705 - loss: 0.6394 - val_accuracy: 0.8378 - val_loss: 0.4473
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.8543 - loss: 0.4055 - val_accuracy: 0.8537 - val_loss: 0.3953
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.8719 - loss: 0.3547 - val_accuracy: 0.8782 - val_loss: 0.3443
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.8828 - loss: 0.3285 - val_accuracy: 0.8959 - val_loss: 0.2907
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 38ms/step - accuracy: 0.8878 - loss: 0.3091 - val_accuracy: 0.9025 - val_loss: 0.2668
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 38ms/step - accuracy: 0.8927 - loss: 0.2958 - val_accuracy: 0.9056 - val_loss: 0.2692
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 39ms/step - accuracy: 0.8964 - loss: 0.2857 - val_accuracy: 0.9015 - val_loss: 0.2819
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 38ms/step - accuracy: 0.8997 - loss: 0.2782 - val_accuracy: 0.9054 - val_loss: 0.2615
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 39ms/step - accuracy: 0.9024 - loss: 0.2677 - val_accuracy: 0.8963 - val_loss: 0.2895
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 38ms/step - accuracy: 0.9039 - loss: 0.2634 - val_accuracy: 0.9146 - val_loss: 0.2448
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 38ms/step - accuracy: 0.9061 - loss: 0.2582 - val_accuracy: 0.8942 - val_loss: 0.3171
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 36s 39ms/step - accuracy: 0.9077 - loss: 0.2509 - val_accuracy: 0.9147 - val_loss: 0.2408
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 35s 37ms/step - accuracy: 0.9095 - loss: 0.2459 - val_accuracy: 0.9072 - val_loss: 0.2672
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 35s 37ms/step - accuracy: 0.9110 - loss: 0.2421 - val_accuracy: 0.9178 - val_loss: 0.2395
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0
# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9322333335876465
# Validation Acc 0.9223999977111816

# %%
# Let's use additional data augmentation
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for CNN input
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Model definition
inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(64, (3, 3), activation='relu', padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(128, (3, 3), activation='relu', padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = GlobalAveragePooling2D()(net)
net = Dense(128, activation='relu')(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation='softmax')(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,370 (435.04 KB)
#  Trainable params: 110,922 (433.29 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Compile model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Training
batch_size = 64
epochs = 50

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/50
# C:\Users\azhidko\.conda\envs\tensor\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 53s 52ms/step - accuracy: 0.6987 - loss: 0.8172 - val_accuracy: 0.7257 - val_loss: 0.8161 - learning_rate: 0.0010
# Epoch 2/50
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.6875 - loss: 0.7903
# C:\Users\azhidko\.conda\envs\tensor\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6875 - loss: 0.7903 - val_accuracy: 0.7335 - val_loss: 0.7870 - learning_rate: 0.0010
# Epoch 3/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.7890 - loss: 0.5672 - val_accuracy: 0.8267 - val_loss: 0.5060 - learning_rate: 0.0010
# Epoch 4/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8281 - loss: 0.6999 - val_accuracy: 0.8230 - val_loss: 0.5161 - learning_rate: 0.0010
# Epoch 5/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8135 - loss: 0.5116 - val_accuracy: 0.8405 - val_loss: 0.4401 - learning_rate: 0.0010
# Epoch 6/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7656 - loss: 0.5910 - val_accuracy: 0.8434 - val_loss: 0.4354 - learning_rate: 0.0010
# Epoch 7/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.8248 - loss: 0.4770 - val_accuracy: 0.8605 - val_loss: 0.3801 - learning_rate: 0.0010
# Epoch 8/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8594 - loss: 0.4669 - val_accuracy: 0.8650 - val_loss: 0.3732 - learning_rate: 0.0010
# Epoch 9/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8327 - loss: 0.4577 - val_accuracy: 0.8441 - val_loss: 0.4174 - learning_rate: 0.0010
# Epoch 10/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8906 - loss: 0.3961 - val_accuracy: 0.8562 - val_loss: 0.3788 - learning_rate: 0.0010
# Epoch 11/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.8388 - loss: 0.4417 - val_accuracy: 0.8397 - val_loss: 0.4296 - learning_rate: 0.0010
# Epoch 12/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9062 - loss: 0.3224 - val_accuracy: 0.8376 - val_loss: 0.4329 - learning_rate: 5.0000e-04
# Epoch 13/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8485 - loss: 0.4119 - val_accuracy: 0.8487 - val_loss: 0.4183 - learning_rate: 5.0000e-04

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.8484717011451721
# Validation Acc 0.8486999869346619

# %% [markdown]
# Reduced Overfitting:
# Compared to previous model (Train Acc ~93%, Val Acc ~92%), the new model with data augmentation has less overfitting
# Slight drop in Accuracy that is expected when using strong regularization (like dropout and augmentation)
# Early Stopping, the model wasn't overfitting further
#
# Let's reduce the strength of augmentations slightly to avoid underfitting
# And add L2 Regularization

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
import numpy as np

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for CNN input
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Data augmentation 
datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.08,
    zoom_range=0.08,
    horizontal_flip=True
)
datagen.fit(x_train)

# Model definition with L2 regularization 
weight_decay = 1e-4
inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(64, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(128, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)

net = GlobalAveragePooling2D()(net)
net = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(weight_decay))(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation='softmax')(net)

model = Model(inputs, outputs)
model.summary()

# Compile model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Training
batch_size = 64
epochs = 50

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,370 (435.04 KB)
#  Trainable params: 110,922 (433.29 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 55s 54ms/step - accuracy: 0.7130 - loss: 0.8132 - val_accuracy: 0.8158 - val_loss: 0.5346 - learning_rate: 0.0010
# Epoch 2/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9062 - loss: 0.4149 - val_accuracy: 0.8178 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 3/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8018 - loss: 0.5733 - val_accuracy: 0.7653 - val_loss: 0.6614 - learning_rate: 0.0010
# Epoch 4/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7969 - loss: 0.6192 - val_accuracy: 0.7709 - val_loss: 0.6513 - learning_rate: 0.0010
# Epoch 5/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.8253 - loss: 0.5194 - val_accuracy: 0.8604 - val_loss: 0.4221 - learning_rate: 0.0010
# Epoch 6/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8594 - loss: 0.3563 - val_accuracy: 0.8559 - val_loss: 0.4300 - learning_rate: 0.0010
# Epoch 7/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.8336 - loss: 0.4961 - val_accuracy: 0.8409 - val_loss: 0.4928 - learning_rate: 0.0010
# Epoch 8/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7656 - loss: 0.6339 - val_accuracy: 0.8436 - val_loss: 0.4817 - learning_rate: 0.0010
# Epoch 9/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.8501 - loss: 0.4539 - val_accuracy: 0.8640 - val_loss: 0.4114 - learning_rate: 5.0000e-04
# Epoch 10/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9219 - loss: 0.5089 - val_accuracy: 0.8684 - val_loss: 0.3987 - learning_rate: 5.0000e-04
# Epoch 11/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8570 - loss: 0.4402 - val_accuracy: 0.8700 - val_loss: 0.4026 - learning_rate: 5.0000e-04
# Epoch 12/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9062 - loss: 0.3310 - val_accuracy: 0.8728 - val_loss: 0.3929 - learning_rate: 5.0000e-04
# Epoch 13/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.8590 - loss: 0.4328 - val_accuracy: 0.8628 - val_loss: 0.4199 - learning_rate: 5.0000e-04
# Epoch 14/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8438 - loss: 0.4431 - val_accuracy: 0.8672 - val_loss: 0.4025 - learning_rate: 5.0000e-04
# Epoch 15/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.8621 - loss: 0.4214 - val_accuracy: 0.8691 - val_loss: 0.3896 - learning_rate: 5.0000e-04
# Epoch 16/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8438 - loss: 0.4319 - val_accuracy: 0.8672 - val_loss: 0.3941 - learning_rate: 5.0000e-04
# Epoch 17/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8649 - loss: 0.4194 - val_accuracy: 0.8751 - val_loss: 0.3830 - learning_rate: 5.0000e-04
# Epoch 18/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8750 - loss: 0.3426 - val_accuracy: 0.8753 - val_loss: 0.3828 - learning_rate: 5.0000e-04
# Epoch 19/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8673 - loss: 0.4082 - val_accuracy: 0.8998 - val_loss: 0.3232 - learning_rate: 5.0000e-04
# Epoch 20/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3721 - val_accuracy: 0.8997 - val_loss: 0.3238 - learning_rate: 5.0000e-04
# Epoch 21/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8674 - loss: 0.4060 - val_accuracy: 0.8961 - val_loss: 0.3286 - learning_rate: 5.0000e-04
# Epoch 22/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7969 - loss: 0.4678 - val_accuracy: 0.8943 - val_loss: 0.3321 - learning_rate: 5.0000e-04
# Epoch 23/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8735 - loss: 0.3924 - val_accuracy: 0.8721 - val_loss: 0.3850 - learning_rate: 2.5000e-04
# Epoch 24/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3514 - val_accuracy: 0.8687 - val_loss: 0.3936 - learning_rate: 2.5000e-04
# Epoch 25/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.8760 - loss: 0.3848 - val_accuracy: 0.8793 - val_loss: 0.3686 - learning_rate: 2.5000e-04
# Epoch 26/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8750 - loss: 0.3705 - val_accuracy: 0.8788 - val_loss: 0.3704 - learning_rate: 1.2500e-04

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.875
# Validation Acc 0.8787999749183655

# %% [markdown]
# Let's increase model capacity

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
import numpy as np

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for CNN input
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Data augmentation (tuned parameters)
datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.08,
    zoom_range=0.08,
    horizontal_flip=True
)
datagen.fit(x_train)

# Model definition with increased capacity and L2 regularization
weight_decay = 1e-4
inputs = Input(shape=(28, 28, 1))

net = Conv2D(64, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(inputs)
net = BatchNormalization()(net)
net = Conv2D(64, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.3)(net)

net = Conv2D(128, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = Conv2D(128, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.4)(net)

net = Conv2D(256, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(weight_decay))(net)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.4)(net)

net = GlobalAveragePooling2D()(net)
net = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(weight_decay))(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation='softmax')(net)

model = Model(inputs, outputs)
model.summary()

# Compile model without label smoothing
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Training
batch_size = 64
epochs = 50

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 28, 28, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 14, 14, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 625,098 (2.38 MB)
#  Trainable params: 623,818 (2.38 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Epoch 1/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 191s 197ms/step - accuracy: 0.7473 - loss: 0.7681 - val_accuracy: 0.8278 - val_loss: 0.5484 - learning_rate: 0.0010
# Epoch 2/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.7969 - loss: 0.5646 - val_accuracy: 0.8249 - val_loss: 0.5599 - learning_rate: 0.0010
# Epoch 3/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 203s 217ms/step - accuracy: 0.8354 - loss: 0.5433 - val_accuracy: 0.8253 - val_loss: 0.5719 - learning_rate: 0.0010
# Epoch 4/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8594 - loss: 0.4372 - val_accuracy: 0.8346 - val_loss: 0.5449 - learning_rate: 0.0010
# Epoch 5/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 206s 220ms/step - accuracy: 0.8553 - loss: 0.4983 - val_accuracy: 0.8557 - val_loss: 0.5118 - learning_rate: 0.0010
# Epoch 6/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8438 - loss: 0.7086 - val_accuracy: 0.8525 - val_loss: 0.5280 - learning_rate: 0.0010
# Epoch 7/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 192s 204ms/step - accuracy: 0.8671 - loss: 0.4846 - val_accuracy: 0.8692 - val_loss: 0.4558 - learning_rate: 0.0010
# Epoch 8/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.8594 - loss: 0.5386 - val_accuracy: 0.8694 - val_loss: 0.4555 - learning_rate: 0.0010
# Epoch 9/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 201s 214ms/step - accuracy: 0.8765 - loss: 0.4654 - val_accuracy: 0.8888 - val_loss: 0.4284 - learning_rate: 0.0010
# Epoch 10/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.7500 - loss: 0.7450 - val_accuracy: 0.8932 - val_loss: 0.4219 - learning_rate: 0.0010
# Epoch 11/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 201s 215ms/step - accuracy: 0.8783 - loss: 0.4662 - val_accuracy: 0.8913 - val_loss: 0.4332 - learning_rate: 0.0010
# Epoch 12/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.8750 - loss: 0.4601 - val_accuracy: 0.8883 - val_loss: 0.4353 - learning_rate: 0.0010
# Epoch 13/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 200s 213ms/step - accuracy: 0.8820 - loss: 0.4639 - val_accuracy: 0.8883 - val_loss: 0.4490 - learning_rate: 0.0010
# Epoch 14/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8438 - loss: 0.4882 - val_accuracy: 0.8898 - val_loss: 0.4443 - learning_rate: 5.0000e-04
# Epoch 15/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 194s 207ms/step - accuracy: 0.8953 - loss: 0.4220 - val_accuracy: 0.9016 - val_loss: 0.3952 - learning_rate: 5.0000e-04
# Epoch 16/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8906 - loss: 0.4866 - val_accuracy: 0.8999 - val_loss: 0.3978 - learning_rate: 5.0000e-04
# Epoch 17/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 183s 196ms/step - accuracy: 0.8999 - loss: 0.3987 - val_accuracy: 0.9049 - val_loss: 0.3710 - learning_rate: 5.0000e-04
# Epoch 18/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8438 - loss: 0.5592 - val_accuracy: 0.9060 - val_loss: 0.3665 - learning_rate: 5.0000e-04
# Epoch 19/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 186s 198ms/step - accuracy: 0.9008 - loss: 0.3910 - val_accuracy: 0.9130 - val_loss: 0.3543 - learning_rate: 5.0000e-04
# Epoch 20/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8438 - loss: 0.4428 - val_accuracy: 0.9129 - val_loss: 0.3536 - learning_rate: 5.0000e-04
# Epoch 21/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 177s 189ms/step - accuracy: 0.9045 - loss: 0.3778 - val_accuracy: 0.9123 - val_loss: 0.3507 - learning_rate: 5.0000e-04
# Epoch 22/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8906 - loss: 0.3545 - val_accuracy: 0.9106 - val_loss: 0.3540 - learning_rate: 5.0000e-04
# Epoch 23/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 179s 191ms/step - accuracy: 0.9044 - loss: 0.3733 - val_accuracy: 0.9092 - val_loss: 0.3547 - learning_rate: 5.0000e-04
# Epoch 24/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9375 - loss: 0.2359 - val_accuracy: 0.9104 - val_loss: 0.3523 - learning_rate: 5.0000e-04
# Epoch 25/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 189s 202ms/step - accuracy: 0.9121 - loss: 0.3482 - val_accuracy: 0.9196 - val_loss: 0.3243 - learning_rate: 2.5000e-04
# Epoch 26/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9688 - loss: 0.3584 - val_accuracy: 0.9193 - val_loss: 0.3257 - learning_rate: 2.5000e-04
# Epoch 27/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 222s 237ms/step - accuracy: 0.9164 - loss: 0.3354 - val_accuracy: 0.9237 - val_loss: 0.3146 - learning_rate: 2.5000e-04
# Epoch 28/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8594 - loss: 0.5774 - val_accuracy: 0.9240 - val_loss: 0.3141 - learning_rate: 2.5000e-04
# Epoch 29/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 231s 246ms/step - accuracy: 0.9150 - loss: 0.3329 - val_accuracy: 0.9225 - val_loss: 0.3131 - learning_rate: 2.5000e-04
# Epoch 30/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9219 - loss: 0.3293 - val_accuracy: 0.9224 - val_loss: 0.3125 - learning_rate: 2.5000e-04
# Epoch 31/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 267s 285ms/step - accuracy: 0.9166 - loss: 0.3250 - val_accuracy: 0.9262 - val_loss: 0.2965 - learning_rate: 2.5000e-04
# Epoch 32/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9531 - loss: 0.2124 - val_accuracy: 0.9268 - val_loss: 0.2967 - learning_rate: 2.5000e-04
# Epoch 33/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 215s 230ms/step - accuracy: 0.9168 - loss: 0.3222 - val_accuracy: 0.9234 - val_loss: 0.2976 - learning_rate: 2.5000e-04
# Epoch 34/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8750 - loss: 0.3799 - val_accuracy: 0.9237 - val_loss: 0.2981 - learning_rate: 2.5000e-04
# Epoch 35/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 207s 220ms/step - accuracy: 0.9207 - loss: 0.3058 - val_accuracy: 0.9211 - val_loss: 0.3041 - learning_rate: 1.2500e-04
# Epoch 36/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9375 - loss: 0.2892 - val_accuracy: 0.9204 - val_loss: 0.3048 - learning_rate: 1.2500e-04
# Epoch 37/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 225s 240ms/step - accuracy: 0.9229 - loss: 0.3000 - val_accuracy: 0.9259 - val_loss: 0.2934 - learning_rate: 1.2500e-04
# Epoch 38/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.9062 - loss: 0.3325 - val_accuracy: 0.9259 - val_loss: 0.2941 - learning_rate: 1.2500e-04
# Epoch 39/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 244s 261ms/step - accuracy: 0.9240 - loss: 0.2959 - val_accuracy: 0.9289 - val_loss: 0.2816 - learning_rate: 1.2500e-04
# Epoch 40/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9219 - loss: 0.3666 - val_accuracy: 0.9286 - val_loss: 0.2817 - learning_rate: 1.2500e-04
# Epoch 41/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 203s 217ms/step - accuracy: 0.9262 - loss: 0.2900 - val_accuracy: 0.9255 - val_loss: 0.2905 - learning_rate: 1.2500e-04
# Epoch 42/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9375 - loss: 0.2321 - val_accuracy: 0.9254 - val_loss: 0.2910 - learning_rate: 1.2500e-04
# Epoch 43/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 203s 217ms/step - accuracy: 0.9265 - loss: 0.2870 - val_accuracy: 0.9271 - val_loss: 0.2800 - learning_rate: 6.2500e-05
# Epoch 44/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9219 - loss: 0.3208 - val_accuracy: 0.9272 - val_loss: 0.2799 - learning_rate: 6.2500e-05
# Epoch 45/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 205s 218ms/step - accuracy: 0.9270 - loss: 0.2832 - val_accuracy: 0.9258 - val_loss: 0.2847 - learning_rate: 6.2500e-05
# Epoch 46/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9219 - loss: 0.2516 - val_accuracy: 0.9261 - val_loss: 0.2846 - learning_rate: 6.2500e-05
# Epoch 47/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 210s 224ms/step - accuracy: 0.9290 - loss: 0.2767 - val_accuracy: 0.9288 - val_loss: 0.2762 - learning_rate: 6.2500e-05
# Epoch 48/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9375 - loss: 0.3092 - val_accuracy: 0.9288 - val_loss: 0.2758 - learning_rate: 6.2500e-05
# Epoch 49/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 226s 241ms/step - accuracy: 0.9294 - loss: 0.2752 - val_accuracy: 0.9290 - val_loss: 0.2703 - learning_rate: 6.2500e-05
# Epoch 50/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.9062 - loss: 0.3092 - val_accuracy: 0.9289 - val_loss: 0.2704 - learning_rate: 6.2500e-05

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.90625
# Validation Acc 0.9289000034332275

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
#   - changed model, increased capacity, used data augmentation, used L2 Regularization
# * Have you tried configurations that did not work out?
#   - The first attempt still had overfitting
